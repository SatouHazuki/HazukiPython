# %% [markdown]
# <a href="https://colab.research.google.com/github/SatouHazuki/HazukiPython/blob/main/tugas_3_intermediet_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-dbe6f84a-e7b5-47b9-abcf-4998cf2408cb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dbe6f84a-e7b5-47b9-abcf-4998cf2408cb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Screenshot (3).png to Screenshot (3).png
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0b2a3040-c87f-4aea-984f-78d6c5c34338" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b2a3040-c87f-4aea-984f-78d6c5c34338">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving IMG_20210422_221231-removebg-preview.png to IMG_20210422_221231-removebg-preview.png
# ...

# %%
import pandas as pd

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fff3b9377cbf> in <module>()
# ----> 1 medals = pd.read_csv('../content/medals.csv',index_col='Unnamed: 0')
#       2 medals.head()
#
# NameError: name 'pd' is not defined

# %%
summer2016 = pd.read_csv('../content/summer2016.csv')
summer2016.drop('Unname: 0',1,inplace=True)
summer2016.head()
# Out:
#     ID  ...   Medal
# 0   62  ...  Bronze
# 1   65  ...  Bronze
# 2   73  ...  Silver
# 3  250  ...  Bronze
# 4  455  ...  Silver
#
# [5 rows x 15 columns]

# %%
import matplotlib.pyplot as plt

# %%
lia = ['hazuki','Narumi','Dev']
lib = [80,95,85]

fig, ax = plt.subplots()
ax.plot(lia,lib)
plt.show()

# %%
lia = ['hazuki','Narumi','Dev']
lib = [80,90,85]

fig, ax = plt.subplots()
ax.plot(lia,lib,marker='d',color = 'green')
plt.show()

# %%
lia = ['hazuki','Narumi','Dev']
lib = [80,75,85]

fig, ax = plt.subplots()
ax.plot(lia,lib,marker='*',color = '#000000',ls=':')
plt.show()

# %%
lia = ['h','Narumi','Dev']
lib = [60,75,85]

fig, ax = plt.subplots()
ax.scatter(lia,lib,)
plt.show()

# %%
lia = ['hazuki','Narumi','Dev']
lib = [60,75,85]

fig, ax = plt.subplots()
ax.scatter(lia,lib,marker='3')
plt.show()

# %%
lia = ['hazuki','Narumi','Dev']
lib = [60,75,85]

fig, ax = plt.subplots()
ax.scatter(lia,lib,marker='3',color='red')
plt.show()

# %%
lia = ['hazuki','Narumi','Dev']
lib = [40,75,85]

fig, ax = plt.subplots()
ax.bar(lia,lib)
plt.show()

# %%
fig,ax = plt.subplots(1,3,figsize=(15,8))
ax[0].bar(medals.index[:3],medals['Gold'][:3])
ax[1].bar(medals.index[:3],medals['Silver'][:3])
ax[2].bar(medals.index[:3],medals['Bronze'][:3])
plt.show()

# %%
medals[['Gold']][:3]
# Out:
#                Gold
# United States   137
# Germany          47
# Great Britain    64

# %%
medals[['Silver']][:3]
# Out:
#                Silver
# United States      52
# Germany            43
# Great Britain      55

# %%
medals[['Bronze']][:3]
